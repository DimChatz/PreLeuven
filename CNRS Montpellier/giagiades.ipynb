# %% [markdown]
# # Script for excel transformations

# %% [markdown]
# Importing libraries

# %%
# Using the import command function you import all the required libraries
# A library is basically a set of ready made functions that you load for use

import pandas as pd # This is a library for data analysis 
pd.set_option('display.max_rows', 120)
import numpy as np

# %% [markdown]
# # Hyperparameters

# %%
IGL = False
IGK = False
IGH = True
filepath = r'C:/Users/xatzo/Downloads/final_IGH.xlsx'

# %% [markdown]
# Reading data

# %%
# Read excel
df = pd.read_excel (filepath)
length = df.shape[0]

# %% [markdown]
# ## Data cleaning and processing

# %% [markdown]
# ### IGK

# %%
if (IGK == True):
    # Create variables here (elsewhere so we dont parse the excel reading everytime)
    reverse = df["ORIENTATION"]

    # Data preprocessing - clearing out useless symbols
    df["L-PART1 START-new"] = df["L-PART1 START"].replace("'", "") # To get rid of the "'" symbol
    start = df["L-PART1 START-new"].fillna(np.float64(0)) # To clear out any nans into floats since the data column are floats

    df["NT TATA-BOX AND L-PART1-new"] = df["NT TATA-BOX AND L-PART1"].replace("'", "")
    df["NT TATA-BOX AND L-PART1-TRUE"] = df["NT TATA-BOX AND L-PART1-new"].fillna(np.float64(0))

    df["TATA-BOX-new"] = df["TATA-BOX"].fillna("'") # replace nans to "'" to get rid of later
    df["TATA-BOX-new2"] = df["TATA-BOX-new"].str.replace("'", "") # as above
    df["TATA-BOX-falseLen"] = df["TATA-BOX-new2"].apply(len) # this calculates the length of the string-empty strings have value 1
    df["TATA-BOX-length"] = df["TATA-BOX-falseLen"].replace(1,0,regex = True) # to make empty strings have value 0

    df["NT CCCT ELEMENT AND L-PART1-new"] = df["NT CCCT ELEMENT AND L-PART1"].replace("'", "")
    df["NT CCCT ELEMENT AND L-PART1-TRUE"] = df["NT CCCT ELEMENT AND L-PART1-new"].fillna(np.float64(0))

    df["CCCT ELEMENT-new"] = df["CCCT ELEMENT"].fillna("'")
    df["CCCT ELEMENT-new2"] = df["CCCT ELEMENT-new"].str.replace("'", "")
    df["CCCT ELEMENT-falseLen"] = df["CCCT ELEMENT-new2"].apply(len)
    df["CCCT ELEMENT-length"] = df["CCCT ELEMENT-falseLen"].replace(1,0,regex = True)

    df["NT E-BOX AND L-PART1-new"] = df["NT E-BOX AND L-PART1"].replace("'", "")
    df["NT E-BOX AND L-PART1-TRUE"] = df["NT E-BOX AND L-PART1-new"].fillna(np.float64(0))

    df["E-BOX-new"] = df["E-BOX"].fillna("'")
    df["E-BOX-new2"] = df["E-BOX-new"].str.replace("'", "")
    df["E-BOX-falseLen"] = df["E-BOX-new2"].apply(len)
    df["E-BOX-length"] = df["E-BOX-falseLen"].replace(1,0,regex = True)

    df["NT TATA-BOX AND L-PART1-2nd-new"] = df["NT TATA-BOX AND L-PART1-2nd"].replace("'", "")
    df["NT TATA-BOX AND L-PART1-2nd-TRUE"] = df["NT TATA-BOX AND L-PART1-2nd-new"].fillna(np.float64(0))

    df["TATA-BOX-2nd-new"] = df["TATA-BOX-2nd"].fillna("'")
    df["TATA-BOX-2nd-new2"] = df["TATA-BOX-2nd-new"].str.replace("'", "")
    df["TATA-BOX-2nd-falseLen"] = df["TATA-BOX-2nd-new2"].apply(len)
    df["TATA-BOX-2nd-length"] = df["TATA-BOX-2nd-falseLen"].replace(1,0,regex = True)

    df["NT CCCT ELEMENT AND L-PART1-2nd-new"] = df["NT CCCT ELEMENT AND L-PART1-2nd"].replace("'", "")
    df["NT CCCT ELEMENT AND L-PART1-2nd-TRUE"] = df["NT CCCT ELEMENT AND L-PART1-2nd-new"].fillna(np.float64(0))

    df["CCCT ELEMENT-2nd-new"] = df["CCCT ELEMENT-2nd"].fillna("'")
    df["CCCT ELEMENT-2nd-new2"] = df["CCCT ELEMENT-2nd-new"].str.replace("'", "")
    df["CCCT ELEMENT-2nd-falseLen"] = df["CCCT ELEMENT-2nd-new2"].apply(len)
    df["CCCT ELEMENT-2nd-length"] = df["CCCT ELEMENT-2nd-falseLen"].replace(1,0,regex = True)

    df["NT CCCT ELEMENT AND L-PART1-3rd-new"] = df["NT CCCT ELEMENT AND L-PART1-3rd"].replace("'", "")
    df["NT CCCT ELEMENT AND L-PART1-3rd-TRUE"] = df["NT CCCT ELEMENT AND L-PART1-3rd-new"].fillna(np.float64(0))

    df["CCCT ELEMENT-3rd-new"] = df["CCCT ELEMENT-3rd"].fillna("'")
    df["CCCT ELEMENT-3rd-new2"] = df["CCCT ELEMENT-3rd-new"].str.replace("'", "")
    df["CCCT ELEMENT-3rd-falseLen"] = df["CCCT ELEMENT-3rd-new2"].apply(len)
    df["CCCT ELEMENT-3rd-length"] = df["CCCT ELEMENT-3rd-falseLen"].replace(1,0,regex = True)

    df["NT 10MER AND L-PART1-new"] = df["NT 10MER AND L-PART1"].replace("'", "")
    df["NT 10MER AND L-PART1-TRUE"] = df["NT 10MER AND L-PART1-new"].fillna(np.float64(0))

    df["10MER-new"] = df["10MER"].fillna("'")
    df["10MER-new2"] = df["10MER-new"].str.replace("'", "")
    df["10MER-falseLen"] = df["10MER-new2"].apply(len)
    df["10MER-length"] = df["10MER-falseLen"].replace(1,0,regex = True)

    df["NT CCCT ELEMENT AND L-PART1-4th-new"] = df["NT CCCT ELEMENT AND L-PART1-4th"].replace("'", "")
    df["NT CCCT ELEMENT AND L-PART1-4th-TRUE"] = df["NT CCCT ELEMENT AND L-PART1-4th-new"].fillna(np.float64(0))

    df["CCCT ELEMENT-4th-new"] = df["CCCT ELEMENT-4th"].fillna("'")
    df["CCCT ELEMENT-4th-new2"] = df["CCCT ELEMENT-4th-new"].str.replace("'", "")
    df["CCCT ELEMENT-4th-falseLen"] = df["CCCT ELEMENT-4th-new2"].apply(len)
    df["CCCT ELEMENT-4th-length"] = df["CCCT ELEMENT-4th-falseLen"].replace(1,0,regex = True)

    df["NT PENTADECAMER AND L-PART1-new"] = df["NT PENTADECAMER AND L-PART1"].replace("'", "")
    df["NT PENTADECAMER AND L-PART1-TRUE"] = df["NT PENTADECAMER AND L-PART1-new"].fillna(np.float64(0))

    df["PENTADECAMER-new"] = df["PENTADECAMER"].fillna("'")
    df["PENTADECAMER-new2"] = df["PENTADECAMER-new"].str.replace("'", "")
    df["PENTADECAMER-falseLen"] = df["PENTADECAMER-new2"].apply(len)
    df["PENTADECAMER-length"] = df["PENTADECAMER-falseLen"].replace(1,0,regex = True)

    df["NT E-BOX AND L-PART1-2nd-new"] = df["NT E-BOX AND L-PART1-2nd"].replace("'", "")
    df["NT E-BOX AND L-PART1-2nd-TRUE"] = df["NT E-BOX AND L-PART1-2nd-new"].fillna(np.float64(0))

    df["E-BOX-2nd-new"] = df["E-BOX-2nd"].fillna("'")
    df["E-BOX-2nd-new2"] = df["E-BOX-2nd-new"].str.replace("'", "")
    df["E-BOX-2nd-falseLen"] = df["E-BOX-2nd-new2"].apply(len)
    df["E-BOX-2nd-length"] = df["E-BOX-2nd-falseLen"].replace(1,0,regex = True)

    df["NT CCCT ELEMENT AND L-PART1-5th-new"] = df["NT CCCT ELEMENT AND L-PART1-5th"].replace("'", "")
    df["NT CCCT ELEMENT AND L-PART1-5th-TRUE"] = df["NT CCCT ELEMENT AND L-PART1-5th-new"].fillna(np.float64(0))

    df["CCCT ELEMENT-5th-new"] = df["CCCT ELEMENT-5th"].fillna("'")
    df["CCCT ELEMENT-5th-new2"] = df["CCCT ELEMENT-5th-new"].str.replace("'", "")
    df["CCCT ELEMENT-5th-falseLen"] = df["CCCT ELEMENT-5th-new2"].apply(len)
    df["CCCT ELEMENT-5th-length"] = df["CCCT ELEMENT-5th-falseLen"].replace(1,0,regex = True)
    
    # Define start and finish
    # create sets of 2 dimnesional arrays with start and finish of the nucleotide sequence
    # start is for e.g. the tata the start of the lpart1 minus the inbetween space minus the length of the tata sequence 
    # end is for tata again the start minus the inbetween space minus 1 to get the index to the right point- the end 
    # TATA BOX
    tata1 = np.zeros((2,df.shape[0]))
    tata2 = np.zeros((2,df.shape[0]))
    cct1 = np.zeros((2,df.shape[0]))
    cct2 = np.zeros((2,df.shape[0]))
    cct3 = np.zeros((2,df.shape[0]))
    cct4 = np.zeros((2,df.shape[0]))
    cct5 = np.zeros((2,df.shape[0]))
    ebox1 = np.zeros((2,df.shape[0]))
    ebox2 = np.zeros((2,df.shape[0]))
    deca = np.zeros((2,df.shape[0]))
    pentadec = np.zeros((2,df.shape[0]))


    for i in range(df.shape[0]):
        if reverse[i]!="rev-compl":
            tata1[:,i] = [start[i] - df["NT TATA-BOX AND L-PART1-TRUE"][i].astype(float)-df["TATA-BOX-length"][i],
              start[i] - df["NT TATA-BOX AND L-PART1-TRUE"][i].astype(float)-1]
            cct1[:,i] = [start[i] - df["NT CCCT ELEMENT AND L-PART1-TRUE"][i].astype(float)-df["CCCT ELEMENT-length"][i],
              start[i] - df["NT CCCT ELEMENT AND L-PART1-TRUE"][i].astype(float)-1]
            ebox1[:,i] = [start[i] - df["NT E-BOX AND L-PART1-TRUE"][i].astype(float)-df["E-BOX-length"][i],
              start[i] - df["NT E-BOX AND L-PART1-TRUE"][i].astype(float)-1]
            tata2[:,i] = [start[i] - df["NT TATA-BOX AND L-PART1-2nd-TRUE"][i].astype(float)-df["TATA-BOX-2nd-length"][i],
              start[i] - df["NT TATA-BOX AND L-PART1-2nd-TRUE"][i].astype(float)-1]
            cct2[:,i] = [start[i] - df["NT CCCT ELEMENT AND L-PART1-2nd-TRUE"][i].astype(float)-df["CCCT ELEMENT-2nd-length"][i],
              start[i] - df["NT CCCT ELEMENT AND L-PART1-2nd-TRUE"][i].astype(float)-1]
            cct3[:,i] = [start[i] - df["NT CCCT ELEMENT AND L-PART1-3rd-TRUE"][i].astype(float)-df["CCCT ELEMENT-3rd-length"][i],
              start[i] - df["NT CCCT ELEMENT AND L-PART1-3rd-TRUE"][i].astype(float)-1]
            deca[:,i] = [start[i] - df["NT 10MER AND L-PART1-TRUE"][i].astype(float)-df["10MER-length"][i],
              start[i] - df["NT 10MER AND L-PART1-TRUE"][i].astype(float)-1]
            cct4[:,i] = [start[i] - df["NT CCCT ELEMENT AND L-PART1-4th-TRUE"][i].astype(float)-df["CCCT ELEMENT-4th-length"][i],
              start[i] - df["NT CCCT ELEMENT AND L-PART1-4th-TRUE"][i].astype(float)-1]
            pentadec[:,i] = [start[i] - df["NT PENTADECAMER AND L-PART1-TRUE"][i].astype(float)-df["PENTADECAMER-length"][i],
              start[i] - df["NT PENTADECAMER AND L-PART1-TRUE"][i].astype(float)-1]
            ebox2[:,i] = [start[i] - df["NT E-BOX AND L-PART1-2nd-TRUE"][i].astype(float)-df["E-BOX-2nd-length"][i],
              start[i] - df["NT E-BOX AND L-PART1-2nd-TRUE"][i].astype(float)-1]
            cct5[:,i] = [start[i] - df["NT CCCT ELEMENT AND L-PART1-5th-TRUE"][i].astype(float)-df["CCCT ELEMENT-5th-length"][i],
              start[i] - df["NT CCCT ELEMENT AND L-PART1-5th-TRUE"][i].astype(float)-1]
        else:
            tata1[:,i] = [start[i] + df["NT TATA-BOX AND L-PART1-TRUE"][i].astype(float)+df["TATA-BOX-length"][i],
              start[i] + df["NT TATA-BOX AND L-PART1-TRUE"][i].astype(float)+1]
            cct1[:,i] = [start[i] + df["NT CCCT ELEMENT AND L-PART1-TRUE"][i].astype(float)+df["CCCT ELEMENT-length"][i],
              start[i] + df["NT CCCT ELEMENT AND L-PART1-TRUE"][i].astype(float)+1]
            ebox1[:,i] = [start[i] + df["NT E-BOX AND L-PART1-TRUE"][i].astype(float)+df["E-BOX-length"][i],
              start[i] + df["NT E-BOX AND L-PART1-TRUE"][i].astype(float)+1]
            tata2[:,i] = [start[i] + df["NT TATA-BOX AND L-PART1-2nd-TRUE"][i].astype(float)+df["TATA-BOX-2nd-length"][i],
              start[i] + df["NT TATA-BOX AND L-PART1-2nd-TRUE"][i].astype(float)+1] 
            cct2[:,i] = [start[i] + df["NT CCCT ELEMENT AND L-PART1-2nd-TRUE"][i].astype(float)+df["CCCT ELEMENT-2nd-length"][i],
              start[i] + df["NT CCCT ELEMENT AND L-PART1-2nd-TRUE"][i].astype(float)+1]
            cct3[:,i] = [start[i] + df["NT CCCT ELEMENT AND L-PART1-3rd-TRUE"][i].astype(float)+df["CCCT ELEMENT-3rd-length"][i],
              start[i] + df["NT CCCT ELEMENT AND L-PART1-3rd-TRUE"][i].astype(float)+1]
            deca[:,i] = [start[i] + df["NT 10MER AND L-PART1-TRUE"][i].astype(float)+df["10MER-length"][i],
              start[i] + df["NT 10MER AND L-PART1-TRUE"][i].astype(float)+1]
            cct4[:,i] = [start[i] + df["NT CCCT ELEMENT AND L-PART1-4th-TRUE"][i].astype(float)+df["CCCT ELEMENT-4th-length"][i],
              start[i] + df["NT CCCT ELEMENT AND L-PART1-4th-TRUE"][i].astype(float)+1]
            pentadec[:,i] = [start[i] + df["NT PENTADECAMER AND L-PART1-TRUE"][i].astype(float)+df["PENTADECAMER-length"][i],
              start[i] + df["NT PENTADECAMER AND L-PART1-TRUE"][i].astype(float)+1]
            ebox2[:,i] = [start[i] + df["NT E-BOX AND L-PART1-2nd-TRUE"][i].astype(float)+df["E-BOX-2nd-length"][i],
              start[i] + df["NT E-BOX AND L-PART1-2nd-TRUE"][i].astype(float)+1]
            cct5[:,i] = [start[i] + df["NT CCCT ELEMENT AND L-PART1-5th-TRUE"][i].astype(float)+df["CCCT ELEMENT-5th-length"][i],
              start[i] + df["NT CCCT ELEMENT AND L-PART1-5th-TRUE"][i].astype(float)+1]

    
    # Parsing data
    # Using a for loop to parse through all the rows
    # Useful for bug/error checking variables
    count1=0
    count2=0
    countall=0
    # main code
    with open(r'C:/Users/xatzo/Downloads/parsingIGK.txt','w') as f: # this is how to properly open a file
        for i in range(length): # create a for loop to parse in the dataset-the inside of the range() must be the number of rows having a content
            countall=countall+1
            if start[i]!=0: # to weed out empty lines
                if reverse[i]=="rev-compl": # to check if it is reverse or not
                    if tata1[0][i] != tata1[1][i]+1: # the +1 is for the anomaly of 0 length - missing sequence
                        f.write("VALD016:102,"+str(int(tata1[0][i]))+"..-"+str(int(tata1[1][i]))+",0"+'\n') 
                        f.write("VALD019:"+'\n')
                    if ebox1[0][i] != ebox1[1][i]+1: 
                        f.write("VALD016:310,"+str(int(ebox1[0][i]))+"..-"+str(int(ebox1[1][i]))+",0"+'\n')
                        f.write("VALD019:"+'\n')
                    if cct4[0][i] != cct4[1][i]+1: 
                        f.write("VALD016:311,"+str(int(cct4[0][i]))+"..-"+str(int(cct4[1][i]))+",0"+'\n')
                        f.write("VALD019:"+'\n')
                    if cct3[0][i] != cct3[1][i]+1: 
                        f.write("VALD016:311,"+str(int(cct3[0][i]))+"..-"+str(int(cct3[1][i]))+",0"+'\n')
                        f.write("VALD019:"+'\n')
                    if cct2[0][i] != cct2[1][i]+1: 
                        f.write("VALD016:311,"+str(int(cct2[0][i]))+"..-"+str(int(cct2[1][i]))+",0"+'\n')
                        f.write("VALD019:"+'\n')
                    if deca[0][i] != deca[1][i]+1: 
                        f.write("VALD016:33,"+str(int(deca[0][i]))+"..-"+str(int(deca[1][i]))+",0"+'\n')
                        f.write("VALD019:"+'\n')
                    if cct1[0][i] != cct1[1][i]+1: 
                        f.write("VALD016:311,"+str(int(cct1[0][i]))+"..-"+str(int(cct1[1][i]))+",0"+'\n')
                        f.write("VALD019:"+'\n')
                    if pentadec[0][i] != pentadec[1][i]+1: 
                        f.write("VALD016:95,"+str(int(pentadec[0][i]))+"..-"+str(int(pentadec[1][i]))+",0"+'\n')
                        f.write("VALD019:"+'\n')
                    if tata2[0][i] != tata2[1][i]+1: # the +1 is for the anomaly of 0 length - missing sequence
                        f.write("VALD016:102,"+str(int(tata2[0][i]))+"..-"+str(int(tata2[1][i]))+",0"+'\n') 
                        f.write("VALD019:"+'\n')
                    if ebox2[0][i] != ebox2[1][i]+1: 
                        f.write("VALD016:310,"+str(int(ebox2[0][i]))+"..-"+str(int(ebox2[1][i]))+",0"+'\n')
                        f.write("VALD019:"+'\n')
                    if cct5[0][i] != cct5[1][i]+1: 
                        f.write("VALD016:311,"+str(int(cct5[0][i]))+"..-"+str(int(cct5[1][i]))+",0"+'\n')
                        f.write("VALD019:"+'\n')
                else:
                    if tata1[0][i] != tata1[1][i]+1: # the +1 is for the anomaly of 0 length - missing sequence
                        f.write("VALD016:102,"+str(int(tata1[0][i]))+".."+str(int(tata1[1][i]))+",0"+'\n') 
                        f.write("VALD019:"+'\n')
                    if ebox1[0][i] != ebox1[1][i]+1: 
                        f.write("VALD016:310,"+str(int(ebox1[0][i]))+".."+str(int(ebox1[1][i]))+",0"+'\n')
                        f.write("VALD019:"+'\n')
                    if cct4[0][i] != cct4[1][i]+1: 
                        f.write("VALD016:311,"+str(int(cct4[0][i]))+".."+str(int(cct4[1][i]))+",0"+'\n')
                        f.write("VALD019:"+'\n')
                    if cct3[0][i] != cct3[1][i]+1: 
                        f.write("VALD016:311,"+str(int(cct3[0][i]))+".."+str(int(cct3[1][i]))+",0"+'\n')
                        f.write("VALD019:"+'\n')
                    if cct2[0][i] != cct2[1][i]+1: 
                        f.write("VALD016:311,"+str(int(cct2[0][i]))+".."+str(int(cct2[1][i]))+",0"+'\n')
                        f.write("VALD019:"+'\n')
                    if deca[0][i] != deca[1][i]+1: 
                        f.write("VALD016:33,"+str(int(deca[0][i]))+".."+str(int(deca[1][i]))+",0"+'\n')
                        f.write("VALD019:"+'\n')
                    if cct1[0][i] != cct1[1][i]+1: 
                        f.write("VALD016:311,"+str(int(cct1[0][i]))+".."+str(int(cct1[1][i]))+",0"+'\n')
                        f.write("VALD019:"+'\n')
                    if pentadec[0][i] != pentadec[1][i]+1: 
                        f.write("VALD016:95,"+str(int(pentadec[0][i]))+".."+str(int(pentadec[1][i]))+",0"+'\n')
                        f.write("VALD019:"+'\n')
                    if tata2[0][i] != tata2[1][i]+1: # the +1 is for the anomaly of 0 length - missing sequence
                        f.write("VALD016:102,"+str(int(tata2[0][i]))+".."+str(int(tata2[1][i]))+",0"+'\n') 
                        f.write("VALD019:"+'\n')
                    if ebox2[0][i] != ebox2[1][i]+1: 
                        f.write("VALD016:310,"+str(int(ebox2[0][i]))+".."+str(int(ebox2[1][i]))+",0"+'\n')
                        f.write("VALD019:"+'\n')
                    if cct5[0][i] != cct5[1][i]+1: 
                        f.write("VALD016:311,"+str(int(cct5[0][i]))+".."+str(int(cct5[1][i]))+",0"+'\n')
                        f.write("VALD019:"+'\n')

# %% [markdown]
# ### IGL

# %%
if (IGL == True):
    # Create variables here (elsewhere so we dont parse the excel reading everytime)
    reverse = df["ORIENTATION"]

    # Data preprocessing - clearing out useless symbols
    df["L-PART1 START-new"] = df["L-PART1 START"].replace("'", "") # To get rid of the "'" symbol
    start = df["L-PART1 START-new"].fillna(np.float64(0)) # To clear out any nans into floats since the data column are floats

    df["NT E-BOX AND L-PART1-new"] = df["NT E-BOX AND L-PART1"].replace("'", "")
    df["NT E-BOX AND L-PART1-TRUE"] = df["NT E-BOX AND L-PART1-new"].fillna(np.float64(0))

    df["E-BOX-new"] = df["E-BOX"].fillna("'")
    df["E-BOX-new2"] = df["E-BOX-new"].str.replace("'", "")
    df["E-BOX-falseLen"] = df["E-BOX-new2"].apply(len)
    df["E-BOX-length"] = df["E-BOX-falseLen"].replace(1,0,regex = True)
    
    df["NT TATA-BOX AND L-PART1-new"] = df["NT TATA-BOX AND L-PART1"].replace("'", "")
    df["NT TATA-BOX AND L-PART1-TRUE"] = df["NT TATA-BOX AND L-PART1-new"].fillna(np.float64(0))

    df["TATA-BOX-new"] = df["TATA-BOX"].fillna("'") # replace nans to "'" to get rid of later
    df["TATA-BOX-new2"] = df["TATA-BOX-new"].str.replace("'", "") # as above
    df["TATA-BOX-falseLen"] = df["TATA-BOX-new2"].apply(len) # this calculates the length of the string-empty strings have value 1
    df["TATA-BOX-length"] = df["TATA-BOX-falseLen"].replace(1,0,regex = True) # to make empty strings have value 0

    df["NT CCCT ELEMENT AND L-PART1-new"] = df["NT CCCT ELEMENT AND L-PART1"].replace("'", "")
    df["NT CCCT ELEMENT AND L-PART1-TRUE"] = df["NT CCCT ELEMENT AND L-PART1-new"].fillna(np.float64(0))

    df["CCCT ELEMENT-new"] = df["CCCT ELEMENT"].fillna("'")
    df["CCCT ELEMENT-new2"] = df["CCCT ELEMENT-new"].str.replace("'", "")
    df["CCCT ELEMENT-falseLen"] = df["CCCT ELEMENT-new2"].apply(len)
    df["CCCT ELEMENT-length"] = df["CCCT ELEMENT-falseLen"].replace(1,0,regex = True)

    df["NT CCCT ELEMENT AND L-PART1-2nd-new"] = df["NT CCCT ELEMENT AND L-PART1-2nd"].replace("'", "")
    df["NT CCCT ELEMENT AND L-PART1-2nd-TRUE"] = df["NT CCCT ELEMENT AND L-PART1-2nd-new"].fillna(np.float64(0))

    df["CCCT ELEMENT-2nd-new"] = df["CCCT ELEMENT-2nd"].fillna("'")
    df["CCCT ELEMENT-2nd-new2"] = df["CCCT ELEMENT-2nd-new"].str.replace("'", "")
    df["CCCT ELEMENT-2nd-falseLen"] = df["CCCT ELEMENT-2nd-new2"].apply(len)
    df["CCCT ELEMENT-2nd-length"] = df["CCCT ELEMENT-2nd-falseLen"].replace(1,0,regex = True)
    
    df["NT 10MER AND L-PART1-new"] = df["NT 10MER AND L-PART1"].replace("'", "")
    df["NT 10MER AND L-PART1-TRUE"] = df["NT 10MER AND L-PART1-new"].fillna(np.float64(0))

    df["10MER-new"] = df["10MER"].fillna("'")
    df["10MER-new2"] = df["10MER-new"].str.replace("'", "")
    df["10MER-falseLen"] = df["10MER-new2"].apply(len)
    df["10MER-length"] = df["10MER-falseLen"].replace(1,0,regex = True)
    
    df["NT TATA-BOX AND L-PART1-2nd-new"] = df["NT TATA-BOX AND L-PART1-2nd"].replace("'", "")
    df["NT TATA-BOX AND L-PART1-2nd-TRUE"] = df["NT TATA-BOX AND L-PART1-2nd-new"].fillna(np.float64(0))

    df["TATA-BOX-2nd-new"] = df["TATA-BOX-2nd"].fillna("'")
    df["TATA-BOX-2nd-new2"] = df["TATA-BOX-2nd-new"].str.replace("'", "")
    df["TATA-BOX-2nd-falseLen"] = df["TATA-BOX-2nd-new2"].apply(len)
    df["TATA-BOX-2nd-length"] = df["TATA-BOX-2nd-falseLen"].replace(1,0,regex = True)

    df["NT CCCT ELEMENT AND L-PART1-3rd-new"] = df["NT CCCT ELEMENT AND L-PART1-3rd"].replace("'", "")
    df["NT CCCT ELEMENT AND L-PART1-3rd-TRUE"] = df["NT CCCT ELEMENT AND L-PART1-3rd-new"].fillna(np.float64(0))

    df["CCCT ELEMENT-3rd-new"] = df["CCCT ELEMENT-3rd"].fillna("'")
    df["CCCT ELEMENT-3rd-new2"] = df["CCCT ELEMENT-3rd-new"].str.replace("'", "")
    df["CCCT ELEMENT-3rd-falseLen"] = df["CCCT ELEMENT-3rd-new2"].apply(len)
    df["CCCT ELEMENT-3rd-length"] = df["CCCT ELEMENT-3rd-falseLen"].replace(1,0,regex = True)

    df["NT PENTADECAMER AND L-PART1-new"] = df["NT PENTADECAMER AND L-PART1"].replace("'", "")
    df["NT PENTADECAMER AND L-PART1-TRUE"] = df["NT PENTADECAMER AND L-PART1-new"].fillna(np.float64(0))

    df["PENTADECAMER-new"] = df["PENTADECAMER"].fillna("'")
    df["PENTADECAMER-new2"] = df["PENTADECAMER-new"].str.replace("'", "")
    df["PENTADECAMER-falseLen"] = df["PENTADECAMER-new2"].apply(len)
    df["PENTADECAMER-length"] = df["PENTADECAMER-falseLen"].replace(1,0,regex = True)
    
    df["NT E-BOX AND L-PART1-2nd-new"] = df["NT E-BOX AND L-PART1-2nd"].replace("'", "")
    df["NT E-BOX AND L-PART1-2nd-TRUE"] = df["NT E-BOX AND L-PART1-2nd-new"].fillna(np.float64(0))

    df["E-BOX-2nd-new"] = df["E-BOX-2nd"].fillna("'")
    df["E-BOX-2nd-new2"] = df["E-BOX-2nd-new"].str.replace("'", "")
    df["E-BOX-2nd-falseLen"] = df["E-BOX-2nd-new2"].apply(len)
    df["E-BOX-2nd-length"] = df["E-BOX-2nd-falseLen"].replace(1,0,regex = True)
    
    # Define start and finish
    # create sets of 2 dimnesional arrays with start and finish of the nucleotide sequence
    # start is for e.g. the tata the start of the lpart1 minus the inbetween space minus the length of the tata sequence 
    # end is for tata again the start minus the inbetween space minus 1 to get the index to the right point- the end 
    tata1 = np.zeros((2,df.shape[0]))
    tata2 = np.zeros((2,df.shape[0]))
    cct1 = np.zeros((2,df.shape[0]))
    cct2 = np.zeros((2,df.shape[0]))
    cct3 = np.zeros((2,df.shape[0]))
    ebox1 = np.zeros((2,df.shape[0]))
    ebox2 = np.zeros((2,df.shape[0]))
    deca = np.zeros((2,df.shape[0]))
    pentadec = np.zeros((2,df.shape[0]))

    
    for i in range(df.shape[0]):
        if reverse[i]!="rev-compl":
            tata1[:,i] = [start[i] - df["NT TATA-BOX AND L-PART1-TRUE"][i].astype(float)-df["TATA-BOX-length"][i],
              start[i] - df["NT TATA-BOX AND L-PART1-TRUE"][i].astype(float)-1]
            cct1[:,i] = [start[i] - df["NT CCCT ELEMENT AND L-PART1-TRUE"][i].astype(float)-df["CCCT ELEMENT-length"][i],
              start[i] - df["NT CCCT ELEMENT AND L-PART1-TRUE"][i].astype(float)-1]
            ebox1[:,i] = [start[i] - df["NT E-BOX AND L-PART1-TRUE"][i].astype(float)-df["E-BOX-length"][i],
              start[i] - df["NT E-BOX AND L-PART1-TRUE"][i].astype(float)-1]
            tata2[:,i] = [start[i] - df["NT TATA-BOX AND L-PART1-2nd-TRUE"][i].astype(float)-df["TATA-BOX-2nd-length"][i],
              start[i] - df["NT TATA-BOX AND L-PART1-2nd-TRUE"][i].astype(float)-1]
            cct2[:,i] = [start[i] - df["NT CCCT ELEMENT AND L-PART1-2nd-TRUE"][i].astype(float)-df["CCCT ELEMENT-2nd-length"][i],
              start[i] - df["NT CCCT ELEMENT AND L-PART1-2nd-TRUE"][i].astype(float)-1]
            cct3[:,i] = [start[i] - df["NT CCCT ELEMENT AND L-PART1-3rd-TRUE"][i].astype(float)-df["CCCT ELEMENT-3rd-length"][i],
              start[i] - df["NT CCCT ELEMENT AND L-PART1-3rd-TRUE"][i].astype(float)-1]
            deca[:,i] = [start[i] - df["NT 10MER AND L-PART1-TRUE"][i].astype(float)-df["10MER-length"][i],
              start[i] - df["NT 10MER AND L-PART1-TRUE"][i].astype(float)-1]
            pentadec[:,i] = [start[i] - df["NT PENTADECAMER AND L-PART1-TRUE"][i].astype(float)-df["PENTADECAMER-length"][i],
              start[i] - df["NT PENTADECAMER AND L-PART1-TRUE"][i].astype(float)-1]
            ebox2[:,i] = [start[i] - df["NT E-BOX AND L-PART1-2nd-TRUE"][i].astype(float)-df["E-BOX-2nd-length"][i],
              start[i] - df["NT E-BOX AND L-PART1-2nd-TRUE"][i].astype(float)-1]
        else:
            tata1[:,i] = [start[i] + df["NT TATA-BOX AND L-PART1-TRUE"][i].astype(float)+df["TATA-BOX-length"][i],
              start[i] + df["NT TATA-BOX AND L-PART1-TRUE"][i].astype(float)+1]
            cct1[:,i] = [start[i] + df["NT CCCT ELEMENT AND L-PART1-TRUE"][i].astype(float)+df["CCCT ELEMENT-length"][i],
              start[i] + df["NT CCCT ELEMENT AND L-PART1-TRUE"][i].astype(float)+1]
            ebox1[:,i] = [start[i] + df["NT E-BOX AND L-PART1-TRUE"][i].astype(float)+df["E-BOX-length"][i],
              start[i] + df["NT E-BOX AND L-PART1-TRUE"][i].astype(float)+1]
            tata2[:,i] = [start[i] + df["NT TATA-BOX AND L-PART1-2nd-TRUE"][i].astype(float)+df["TATA-BOX-2nd-length"][i],
              start[i] + df["NT TATA-BOX AND L-PART1-2nd-TRUE"][i].astype(float)+1] 
            cct2[:,i] = [start[i] + df["NT CCCT ELEMENT AND L-PART1-2nd-TRUE"][i].astype(float)+df["CCCT ELEMENT-2nd-length"][i],
              start[i] + df["NT CCCT ELEMENT AND L-PART1-2nd-TRUE"][i].astype(float)+1]
            cct3[:,i] = [start[i] + df["NT CCCT ELEMENT AND L-PART1-3rd-TRUE"][i].astype(float)+df["CCCT ELEMENT-3rd-length"][i],
              start[i] + df["NT CCCT ELEMENT AND L-PART1-3rd-TRUE"][i].astype(float)+1]
            deca[:,i] = [start[i] + df["NT 10MER AND L-PART1-TRUE"][i].astype(float)+df["10MER-length"][i],
              start[i] + df["NT 10MER AND L-PART1-TRUE"][i].astype(float)+1]
            pentadec[:,i] = [start[i] + df["NT PENTADECAMER AND L-PART1-TRUE"][i].astype(float)+df["PENTADECAMER-length"][i],
              start[i] + df["NT PENTADECAMER AND L-PART1-TRUE"][i].astype(float)+1]
            ebox2[:,i] = [start[i] + df["NT E-BOX AND L-PART1-2nd-TRUE"][i].astype(float)+df["E-BOX-2nd-length"][i],
              start[i] + df["NT E-BOX AND L-PART1-2nd-TRUE"][i].astype(float)+1]
            

    # Parsing data
    # Using a for loop to parse through all the rows
    # Useful for bug/error checking variables
    count1=0
    count2=0
    countall=0
    # main code
    with open(r'C:/Users/xatzo/Downloads/parsingIGL.txt','w') as f: # this is how to properly open a file
        for i in range(length): # create a for loop to parse in the dataset-the inside of the range() must be the number of rows having a content
            countall=countall+1
            if start[i]!=0: # to weed out empty lines
                if reverse[i]=="rev-compl": # to check if it is reverse or not
                    if tata1[0][i] != tata1[1][i]+1: # the +1 is for the anomaly of 0 length - missing sequence
                        f.write("VALD016:102,"+str(int(tata1[0][i]))+"..-"+str(int(tata1[1][i]))+",0"+'\n') 
                        f.write("VALD019:"+'\n')
                    if ebox1[0][i] != ebox1[1][i]+1: 
                        f.write("VALD016:310,"+str(int(ebox1[0][i]))+"..-"+str(int(ebox1[1][i]))+",0"+'\n')
                        f.write("VALD019:"+'\n')
                    if ebox2[0][i] != ebox2[1][i]+1: 
                        f.write("VALD016:310,"+str(int(ebox2[0][i]))+"..-"+str(int(ebox2[1][i]))+",0"+'\n')
                        f.write("VALD019:"+'\n')
                    if cct3[0][i] != cct3[1][i]+1: 
                        f.write("VALD016:311,"+str(int(cct3[0][i]))+"..-"+str(int(cct3[1][i]))+",0"+'\n')
                        f.write("VALD019:"+'\n')
                    if cct2[0][i] != cct2[1][i]+1: 
                        f.write("VALD016:311,"+str(int(cct2[0][i]))+"..-"+str(int(cct2[1][i]))+",0"+'\n')
                        f.write("VALD019:"+'\n')
                    if deca[0][i] != deca[1][i]+1: 
                        f.write("VALD016:33,"+str(int(deca[0][i]))+"..-"+str(int(deca[1][i]))+",0"+'\n')
                        f.write("VALD019:"+'\n')
                    if cct1[0][i] != cct1[1][i]+1: 
                        f.write("VALD016:311,"+str(int(cct1[0][i]))+"..-"+str(int(cct1[1][i]))+",0"+'\n')
                        f.write("VALD019:"+'\n')
                    if pentadec[0][i] != pentadec[1][i]+1: 
                        f.write("VALD016:95,"+str(int(pentadec[0][i]))+"..-"+str(int(pentadec[1][i]))+",0"+'\n')
                        f.write("VALD019:"+'\n')
                    if tata2[0][i] != tata2[1][i]+1: # the +1 is for the anomaly of 0 length - missing sequence
                        f.write("VALD016:102,"+str(int(tata2[0][i]))+"..-"+str(int(tata2[1][i]))+",0"+'\n') 
                        f.write("VALD019:"+'\n')
                else:
                    if tata1[0][i] != tata1[1][i]+1: # the +1 is for the anomaly of 0 length - missing sequence
                        f.write("VALD016:102,"+str(int(tata1[0][i]))+".."+str(int(tata1[1][i]))+",0"+'\n') 
                        f.write("VALD019:"+'\n')
                    if ebox1[0][i] != ebox1[1][i]+1: 
                        f.write("VALD016:310,"+str(int(ebox1[0][i]))+".."+str(int(ebox1[1][i]))+",0"+'\n')
                        f.write("VALD019:"+'\n')
                    if ebox2[0][i] != ebox2[1][i]+1: 
                        f.write("VALD016:310,"+str(int(ebox2[0][i]))+".."+str(int(ebox2[1][i]))+",0"+'\n')
                        f.write("VALD019:"+'\n')
                    if cct3[0][i] != cct3[1][i]+1: 
                        f.write("VALD016:311,"+str(int(cct3[0][i]))+".."+str(int(cct3[1][i]))+",0"+'\n')
                        f.write("VALD019:"+'\n')
                    if cct2[0][i] != cct2[1][i]+1: 
                        f.write("VALD016:311,"+str(int(cct2[0][i]))+".."+str(int(cct2[1][i]))+",0"+'\n')
                        f.write("VALD019:"+'\n')
                    if deca[0][i] != deca[1][i]+1: 
                        f.write("VALD016:33,"+str(int(deca[0][i]))+".."+str(int(deca[1][i]))+",0"+'\n')
                        f.write("VALD019:"+'\n')
                    if cct1[0][i] != cct1[1][i]+1: 
                        f.write("VALD016:311,"+str(int(cct1[0][i]))+".."+str(int(cct1[1][i]))+",0"+'\n')
                        f.write("VALD019:"+'\n')
                    if pentadec[0][i] != pentadec[1][i]+1: 
                        f.write("VALD016:95,"+str(int(pentadec[0][i]))+".."+str(int(pentadec[1][i]))+",0"+'\n')
                        f.write("VALD019:"+'\n')
                    if tata2[0][i] != tata2[1][i]+1: # the +1 is for the anomaly of 0 length - missing sequence
                        f.write("VALD016:102,"+str(int(tata2[0][i]))+".."+str(int(tata2[1][i]))+",0"+'\n') 
                        f.write("VALD019:"+'\n')

# %% [markdown]
# ### IGH

# %%
if (IGH == True):
    # Create variables here (elsewhere so we dont parse the excel reading everytime)
    reverse = df["ORIENTATION"]

    # Data preprocessing - clearing out useless symbols
    df["L-PART1 START-new"] = df["L-PART1 START"].replace("'", "") # To get rid of the "'" symbol
    start = df["L-PART1 START-new"].fillna(np.float64(0)) # To clear out any nans into floats since the data column are floats

    df["nt between E_BOX and L-PART1-new"] = df["nt between E_BOX and L-PART1"].replace("'", "")
    df["nt between E_BOX and L-PART1-TRUE"] = df["nt between E_BOX and L-PART1-new"].fillna(np.float64(0))

    df["E_BOX-new"] = df["E_BOX"].fillna("'")
    df["E_BOX-new2"] = df["E_BOX-new"].str.replace("'", "")
    df["E_BOX-falseLen"] = df["E_BOX-new2"].apply(len)
    df["E_BOX-length"] = df["E_BOX-falseLen"].replace(1,0,regex = True)
    
    df["nt between TATA_BOX and L-PART1-new"] = df["nt between TATA_BOX and L-PART1"].replace("'", "")
    df["nt between TATA_BOX and L-PART1-TRUE"] = df["nt between TATA_BOX and L-PART1-new"].fillna(np.float64(0))

    df["TATA_BOX-new"] = df["TATA_BOX"].fillna("'") # replace nans to "'" to get rid of later
    df["TATA_BOX-new2"] = df["TATA_BOX-new"].str.replace("'", "") # as above
    df["TATA_BOX-falseLen"] = df["TATA_BOX-new2"].apply(len) # this calculates the length of the string-empty strings have value 1
    df["TATA_BOX-length"] = df["TATA_BOX-falseLen"].replace(1,0,regex = True) # to make empty strings have value 0

    df["nt between E_BOX and L-PART1-2nd-new"] = df["nt between E_BOX and L-PART1-2nd"].replace("'", "")
    df["nt between E_BOX and L-PART1-2nd-TRUE"] = df["nt between E_BOX and L-PART1-2nd-new"].fillna(np.float64(0))

    df["E_BOX-2nd-new"] = df["E_BOX-2nd"].fillna("'")
    df["E_BOX-2nd-new2"] = df["E_BOX-2nd-new"].str.replace("'", "")
    df["E_BOX-2nd-falseLen"] = df["E_BOX-2nd-new2"].apply(len)
    df["E_BOX-2nd-length"] = df["E_BOX-2nd-falseLen"].replace(1,0,regex = True)
    
    df["nt between OCTAMER and L-PART1-new"] = df["nt between OCTAMER and L-PART1"].replace("'", "")
    df["nt between OCTAMER and L-PART1-TRUE"] = df["nt between OCTAMER and L-PART1-new"].fillna(np.float64(0))

    df["OCTAMER-new"] = df["OCTAMER"].fillna("'")
    df["OCTAMER-new2"] = df["OCTAMER-new"].str.replace("'", "")
    df["OCTAMER-falseLen"] = df["OCTAMER-new2"].apply(len)
    df["OCTAMER-length"] = df["OCTAMER-falseLen"].replace(1,0,regex = True)

    df["nt between TATA_BOX and L-PART1-2nd-new"] = df["nt between TATA_BOX and L-PART1-2nd"].replace("'", "")
    df["nt between TATA_BOX and L-PART1-2nd-TRUE"] = df["nt between TATA_BOX and L-PART1-2nd-new"].fillna(np.float64(0))

    df["TATA_BOX-2nd-new"] = df["TATA_BOX-2nd"].fillna("'")
    df["TATA_BOX-2nd-new2"] = df["TATA_BOX-2nd-new"].str.replace("'", "")
    df["TATA_BOX-2nd-falseLen"] = df["TATA_BOX-2nd-new2"].apply(len)
    df["TATA_BOX-2nd-length"] = df["TATA_BOX-2nd-falseLen"].replace(1,0,regex = True)
    
    df["nt between PYR-RICH and L-PART1-new"] = df["nt between PYR-RICH and L-PART1"].replace("'", "")
    df["nt between PYR-RICH and L-PART1-TRUE"] = df["nt between PYR-RICH and L-PART1-new"].fillna(np.float64(0))

    df["PYR-RICH-new"] = df["PYR-RICH"].fillna("'")
    df["PYR-RICH-new2"] = df["PYR-RICH-new"].str.replace("'", "")
    df["PYR-RICH-falseLen"] = df["PYR-RICH-new2"].apply(len)
    df["PYR-RICH-length"] = df["PYR-RICH-falseLen"].replace(1,0,regex = True)
    
    df["nt between HEPTANUCLEOTIDE and L-PART1-new"] = df["nt between HEPTANUCLEOTIDE and L-PART1"].replace("'", "")
    df["nt between HEPTANUCLEOTIDE and L-PART1-TRUE"] = df["nt between HEPTANUCLEOTIDE and L-PART1-new"].fillna(np.float64(0))

    df["HEPTANUCLEOTIDE-new"] = df["HEPTANUCLEOTIDE"].fillna("'")
    df["HEPTANUCLEOTIDE-new2"] = df["HEPTANUCLEOTIDE-new"].str.replace("'", "")
    df["HEPTANUCLEOTIDE-falseLen"] = df["HEPTANUCLEOTIDE-new2"].apply(len)
    df["HEPTANUCLEOTIDE-length"] = df["HEPTANUCLEOTIDE-falseLen"].replace(1,0,regex = True)
    
    df["nt between TATA_BOX and L-PART1-3rd-new"] = df["nt between TATA_BOX and L-PART1-3rd"].replace("'", "")
    df["nt between TATA_BOX and L-PART1-3rd-TRUE"] = df["nt between TATA_BOX and L-PART1-3rd-new"].fillna(np.float64(0))

    df["TATA_BOX-3rd-new"] = df["TATA_BOX-3rd"].fillna("'") # replace nans to "'" to get rid of later
    df["TATA_BOX-3rd-new2"] = df["TATA_BOX-3rd-new"].str.replace("'", "") # as above
    df["TATA_BOX-3rd-falseLen"] = df["TATA_BOX-3rd-new2"].apply(len) # this calculates the length of the string-empty strings have value 1
    df["TATA_BOX-3rd-length"] = df["TATA_BOX-3rd-falseLen"].replace(1,0,regex = True) # to make empty strings have value 0

    df["nt between PYR-RICH and L-PART1-2nd-new"] = df["nt between PYR-RICH and L-PART1-2nd"].replace("'", "")
    df["nt between PYR-RICH and L-PART1-2nd-TRUE"] = df["nt between PYR-RICH and L-PART1-2nd-new"].fillna(np.float64(0))

    df["PYR-RICH-2nd-new"] = df["PYR-RICH-2nd"].fillna("'")
    df["PYR-RICH-2nd-new2"] = df["PYR-RICH-2nd-new"].str.replace("'", "")
    df["PYR-RICH-2nd-falseLen"] = df["PYR-RICH-2nd-new2"].apply(len)
    df["PYR-RICH-2nd-length"] = df["PYR-RICH-2nd-falseLen"].replace(1,0,regex = True)
    
    # Define start and finish
    # create sets of 2 dimnesional arrays with start and finish of the nucleotide sequence
    # start is for e.g. the tata the start of the lpart1 minus the inbetween space minus the length of the tata sequence 
    # end is for tata again the start minus the inbetween space minus 1 to get the index to the right point- the end 
    tata1 = np.zeros((2,df.shape[0]))
    tata2 = np.zeros((2,df.shape[0]))
    tata3 = np.zeros((2,df.shape[0]))
    pyri1 = np.zeros((2,df.shape[0]))
    pyri2 = np.zeros((2,df.shape[0]))
    hepta = np.zeros((2,df.shape[0]))
    octa = np.zeros((2,df.shape[0]))
    ebox1 = np.zeros((2,df.shape[0]))
    ebox2 = np.zeros((2,df.shape[0]))
    deca = np.zeros((2,df.shape[0]))
    pentadec = np.zeros((2,df.shape[0]))


    for i in range(df.shape[0]):
        if reverse[i]!="rev-compl":
            tata1[:,i] = [start[i] - df["nt between TATA_BOX and L-PART1-TRUE"][i].astype(float)-df["TATA_BOX-length"][i],
              start[i] - df["nt between TATA_BOX and L-PART1-TRUE"][i].astype(float)-1]
            pyri2[:,i] = [start[i] - df["nt between PYR-RICH and L-PART1-2nd-TRUE"][i].astype(float)-df["PYR-RICH-length"][i],
              start[i] - df["nt between PYR-RICH and L-PART1-2nd-TRUE"][i].astype(float)-1]
            ebox1[:,i] = [start[i] - df["nt between E_BOX and L-PART1-TRUE"][i].astype(float)-df["E_BOX-length"][i],
              start[i] - df["nt between E_BOX and L-PART1-TRUE"][i].astype(float)-1]
            tata2[:,i] = [start[i] - df["nt between TATA_BOX and L-PART1-2nd-TRUE"][i].astype(float)-df["TATA_BOX-2nd-length"][i],
              start[i] - df["nt between TATA_BOX and L-PART1-2nd-TRUE"][i].astype(float)-1]
            pyri1[:,i] = [start[i] - df["nt between PYR-RICH and L-PART1-2nd-TRUE"][i].astype(float)-df["PYR-RICH-length"][i],
              start[i] - df["nt between PYR-RICH and L-PART1-2nd-TRUE"][i].astype(float)-1]
            tata3[:,i] = [start[i] - df["nt between TATA_BOX and L-PART1-3rd-TRUE"][i].astype(float)-df["TATA_BOX-3rd-length"][i],
              start[i] - df["nt between TATA_BOX and L-PART1-3rd-TRUE"][i].astype(float)-1]
            octa[:,i] = [start[i] - df["nt between OCTAMER and L-PART1-TRUE"][i].astype(float)-df["OCTAMER-length"][i],
              start[i] - df["nt between OCTAMER and L-PART1-TRUE"][i].astype(float)-1]
            hepta[:,i] = [start[i] - df["nt between HEPTANUCLEOTIDE and L-PART1-TRUE"][i].astype(float)-df["HEPTANUCLEOTIDE-length"][i],
              start[i] - df["nt between HEPTANUCLEOTIDE and L-PART1-TRUE"][i].astype(float)-1]
            ebox2[:,i] = [start[i] - df["nt between E_BOX and L-PART1-2nd-TRUE"][i].astype(float)-df["E_BOX-2nd-length"][i],
              start[i] - df["nt between E_BOX and L-PART1-2nd-TRUE"][i].astype(float)-1]
        else:
            tata1[:,i] = [start[i] + df["nt between TATA_BOX and L-PART1-TRUE"][i].astype(float)+df["TATA_BOX-length"][i],
              start[i] + df["nt between TATA_BOX and L-PART1-TRUE"][i].astype(float)+1]
            pyri2[:,i] = [start[i] - df["nt between PYR-RICH and L-PART1-2nd-TRUE"][i].astype(float)-df["PYR-RICH-length"][i],
              start[i] - df["nt between PYR-RICH and L-PART1-2nd-TRUE"][i].astype(float)-1]
            ebox1[:,i] = [start[i] + df["nt between E_BOX and L-PART1-TRUE"][i].astype(float)+df["E_BOX-length"][i],
              start[i] + df["nt between E_BOX and L-PART1-TRUE"][i].astype(float)+1]
            tata2[:,i] = [start[i] + df["nt between TATA_BOX and L-PART1-2nd-TRUE"][i].astype(float)+df["TATA_BOX-2nd-length"][i],
              start[i] + df["nt between TATA_BOX and L-PART1-2nd-TRUE"][i].astype(float)+1] 
            pyri2[:,i] = [start[i] - df["nt between PYR-RICH and L-PART1-2nd-TRUE"][i].astype(float)-df["PYR-RICH-length"][i],
              start[i] - df["nt between PYR-RICH and L-PART1-2nd-TRUE"][i].astype(float)-1]
            tata3[:,i] = [start[i] - df["nt between TATA_BOX and L-PART1-3rd-TRUE"][i].astype(float)-df["TATA_BOX-3rd-length"][i],
              start[i] - df["nt between TATA_BOX and L-PART1-3rd-TRUE"][i].astype(float)-1]
            octa[:,i] = [start[i] - df["nt between OCTAMER and L-PART1-TRUE"][i].astype(float)-df["OCTAMER-length"][i],
              start[i] - df["nt between OCTAMER and L-PART1-TRUE"][i].astype(float)-1]
            hepta[:,i] = [start[i] - df["nt between HEPTANUCLEOTIDE and L-PART1-TRUE"][i].astype(float)-df["HEPTANUCLEOTIDE-length"][i],
              start[i] - df["nt between HEPTANUCLEOTIDE and L-PART1-TRUE"][i].astype(float)-1]
            ebox2[:,i] = [start[i] + df["nt between E_BOX and L-PART1-2nd-TRUE"][i].astype(float)+df["E_BOX-2nd-length"][i],
              start[i] + df["nt between E_BOX and L-PART1-2nd-TRUE"][i].astype(float)+1]
    # Parsing data
    # Using a for loop to parse through all the rows
    # Useful for bug/error checking variables
    count1=0
    count2=0
    countall=0
    # main code
    with open(r'C:/Users/xatzo/Downloads/parsingIGH.txt','w') as f: # this is how to properly open a file
        for i in range(length): # create a for loop to parse in the dataset-the inside of the range() must be the number of rows having a content
            countall=countall+1
            if start[i]!=0: # to weed out empty lines
                if reverse[i]=="rev-compl": # to check if it is reverse or not
                    if tata1[0][i] != tata1[1][i]+1: # the +1 is for the anomaly of 0 length - missing sequence
                        f.write("VALD016:102,"+str(int(tata1[0][i]))+"..-"+str(int(tata1[1][i]))+",0"+'\n') 
                        f.write("VALD019:"+'\n')
                    if tata3[0][i] != tata3[1][i]+1: # the +1 is for the anomaly of 0 length - missing sequence
                        f.write("VALD016:102,"+str(int(tata3[0][i]))+"..-"+str(int(tata3[1][i]))+",0"+'\n') 
                        f.write("VALD019:"+'\n')
                    if ebox1[0][i] != ebox1[1][i]+1: 
                        f.write("VALD016:310,"+str(int(ebox1[0][i]))+"..-"+str(int(ebox1[1][i]))+",0"+'\n')
                        f.write("VALD019:"+'\n')
                    if hepta[0][i] != hepta[1][i]+1: 
                        f.write("VALD016:52,"+str(int(hepta[0][i]))+"..-"+str(int(hepta[1][i]))+",0"+'\n')
                        f.write("VALD019:"+'\n')
                    if octa[0][i] != octa[1][i]+1: 
                        f.write("VALD016:93,"+str(int(octa[0][i]))+"..-"+str(int(octa[1][i]))+",0"+'\n')
                        f.write("VALD019:"+'\n')
                    if pyri[0][i] != pyri[1][i]+1: 
                        f.write("VALD016:97,"+str(int(pyri[0][i]))+"..-"+str(int(pyri[1][i]))+",0"+'\n')
                        f.write("VALD019:"+'\n')
                    if pyri2[0][i] != pyri2[1][i]+1: 
                        f.write("VALD016:97,"+str(int(pyri2[0][i]))+"..-"+str(int(pyri2[1][i]))+",0"+'\n')
                        f.write("VALD019:"+'\n')
                    if tata2[0][i] != tata2[1][i]+1: # the +1 is for the anomaly of 0 length - missing sequence
                        f.write("VALD016:102,"+str(int(tata2[0][i]))+"..-"+str(int(tata2[1][i]))+",0"+'\n') 
                        f.write("VALD019:"+'\n')
                    if ebox2[0][i] != ebox2[1][i]+1: 
                        f.write("VALD016:310,"+str(int(ebox2[0][i]))+"..-"+str(int(ebox2[1][i]))+",0"+'\n')
                        f.write("VALD019:"+'\n')
                else:
                    if tata1[0][i] != tata1[1][i]+1: # the +1 is for the anomaly of 0 length - missing sequence
                        f.write("VALD016:102,"+str(int(tata1[0][i]))+".."+str(int(tata1[1][i]))+",0"+'\n') 
                        f.write("VALD019:"+'\n')
                    if tata3[0][i] != tata3[1][i]+1: # the +1 is for the anomaly of 0 length - missing sequence
                        f.write("VALD016:102,"+str(int(tata3[0][i]))+".."+str(int(tata3[1][i]))+",0"+'\n') 
                        f.write("VALD019:"+'\n')
                    if ebox1[0][i] != ebox1[1][i]+1: 
                        f.write("VALD016:310,"+str(int(ebox1[0][i]))+".."+str(int(ebox1[1][i]))+",0"+'\n')
                        f.write("VALD019:"+'\n')
                    if hepta[0][i] != hepta[1][i]+1: 
                        f.write("VALD016:52,"+str(int(hepta[0][i]))+".."+str(int(hepta[1][i]))+",0"+'\n')
                        f.write("VALD019:"+'\n')
                    if octa[0][i] != octa[1][i]+1: 
                        f.write("VALD016:93,"+str(int(octa[0][i]))+".."+str(int(octa[1][i]))+",0"+'\n')
                        f.write("VALD019:"+'\n')
                    if pyri[0][i] != pyri[1][i]+1: 
                        f.write("VALD016:97,"+str(int(pyri[0][i]))+".."+str(int(pyri[1][i]))+",0"+'\n')
                        f.write("VALD019:"+'\n')
                    if pyri2[0][i] != pyri2[1][i]+1: 
                        f.write("VALD016:97,"+str(int(pyri2[0][i]))+".."+str(int(pyri2[1][i]))+",0"+'\n')
                        f.write("VALD019:"+'\n')
                    if tata2[0][i] != tata2[1][i]+1: # the +1 is for the anomaly of 0 length - missing sequence
                        f.write("VALD016:102,"+str(int(tata2[0][i]))+".."+str(int(tata2[1][i]))+",0"+'\n') 
                        f.write("VALD019:"+'\n')
                    if ebox2[0][i] != ebox2[1][i]+1: 
                        f.write("VALD016:310,"+str(int(ebox2[0][i]))+".."+str(int(ebox2[1][i]))+",0"+'\n')
                        f.write("VALD019:"+'\n')
