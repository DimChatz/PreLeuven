# %% [markdown]
# # Code for creating plots for the different Morris-Lecar method

# %%
from brian2 import *
# %matplotlib inline

# %% [markdown]
# bw=0

# %%
rates0=[4,16,24,47,77,94,113,136,166,187,202]
Icurrent0=[36.75,36.85,37,37.8,40,42,45,50,60,70,80]
plot(Icurrent0,rates0,'.')
xlabel("I")
ylabel("Firing rate (Hz)")
axis([30,90,0,200])
# Out:
# [30, 90, 0, 200]

# %% [markdown]
# bw=-13

# %%
rates13=[63,70,75,80,87,112,135,152,165,176]
Icurrent13=[42.5,43,43.5,44,45,50,57,64,71,78]
plot(Icurrent13,rates13,'.')
xlabel("I")
ylabel("Firing rate (Hz)")
axis([30,90,0,200])
# Out:
# [30, 90, 0, 200]

# %% [markdown]
# bw=-21

# %%
rates21=[1,1,1,1,1]
Icurrent21=[60,65,70,75,80]
plot(Icurrent21,rates21,'.')
xlabel("I")
ylabel("Firing rate (Hz)")
axis([40,90,0,5])
# Out:
# [40, 90, 0, 5]
